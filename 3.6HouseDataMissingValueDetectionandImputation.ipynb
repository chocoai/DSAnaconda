# %%
import pandas
df = pandas.read_csv('data/house_data.csv')

# %%
df.head(3)
# Out:
#                               標題  产权性质  住宅类别 建筑类别  参考月供     年代    建筑面积  \
# 0  急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权  普通住宅   板楼   NaN  1989年   70.40
# 1       世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权  普通住宅   塔楼   NaN  1989年   49.82
# 2              大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN   NaN  2005年  288.30
#
#          户型        楼层      物 业 费 物业类型   结构   装修      總價
# 0  2室2厅1厨1卫   中层(共6层)       暂无资料   住宅   平层  精装修    30.6
# 1  2室1厅0厨1卫   中层(共6层)    1元/平米・月   住宅   平层  简装修   418.0
# 2  4室2厅0厨2卫  高层(共40层)  3.5元/平米・月   住宅  NaN  精装修  2650.0

# %% [markdown]
# ## 舍弃第一栏

# %%
df = pandas.read_csv('data/house_data.csv',index_col=0)

# %%
df.head()
# Out:
#                               標題  产权性质  住宅类别 建筑类别  参考月供     年代    建筑面积  \
# 0  急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权  普通住宅   板楼   NaN  1989年   70.40
# 1       世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权  普通住宅   塔楼   NaN  1989年   49.82
# 2              大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN   NaN  2005年  288.30
# 3       精装二房全明户型户型好客厅主卧朝南带阳台看房方便   商品房   NaN   板楼   NaN  1994年   56.00
# 4   满五税费少,房东接受置换客户,房东这边房子已经看好,急卖  个人产权  普通住宅   钢混   NaN  1998年   58.00
#
#          户型        楼层      物 业 费 物业类型   结构   装修      總價
# 0  2室2厅1厨1卫   中层(共6层)       暂无资料   住宅   平层  精装修    30.6
# 1  2室1厅0厨1卫   中层(共6层)    1元/平米・月   住宅   平层  简装修   418.0
# 2  4室2厅0厨2卫  高层(共40层)  3.5元/平米・月   住宅  NaN  精装修  2650.0
# 3  2室1厅1厨1卫   高层(共6层)  0.4元/平米・月   住宅   平层  简装修   280.0
# 4  2室1厅1厨1卫   高层(共6层)  0.4元/平米・月   住宅   平层  精装修   190.0

# %% [markdown]
# ## 将"暂无资料"变成缺失值

# %%
df[df['物 业 费'] == '暂无资料']
# Out:
# Empty DataFrame
# Columns: [標題, 产权性质, 住宅类别, 建筑类别, 参考月供, 年代, 建筑面积, 户型, 楼层, 物 业 费, 物业类型, 结构, 装修, 總價]
# Index: []

# %%
import numpy as np
import pandas
df = pandas.read_csv('data/house_data.csv',index_col=0)
df.ix[df['物 业 费'] == '暂无资料','物 业 费'] = np.nan 
df.head()
# Out:
# D:\Anaconda3.6.5fille\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   after removing the cwd from sys.path.
#                               標題  产权性质  住宅类别 建筑类别  参考月供     年代    建筑面积  \
# 0  急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权  普通住宅   板楼   NaN  1989年   70.40
# 1       世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权  普通住宅   塔楼   NaN  1989年   49.82
# 2              大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN   NaN  2005年  288.30
# 3       精装二房全明户型户型好客厅主卧朝南带阳台看房方便   商品房   NaN   板楼   NaN  1994年   56.00
# 4   满五税费少,房东接受置换客户,房东这边房子已经看好,急卖  个人产权  普通住宅   钢混   NaN  1998年   58.00
#
#          户型        楼层      物 业 费 物业类型   结构   装修      總價
# 0  2室2厅1厨1卫   中层(共6层)        NaN   住宅   平层  精装修    30.6
# 1  2室1厅0厨1卫   中层(共6层)    1元/平米・月   住宅   平层  简装修   418.0
# ...

# %%
df[df['物 业 费'] == '暂无资料']
# Out:
# Empty DataFrame
# Columns: [標題, 产权性质, 住宅类别, 建筑类别, 参考月供, 年代, 建筑面积, 户型, 楼层, 物 业 费, 物业类型, 结构, 装修, 總價]
# Index: []

# %%
import pandas
df = pandas.read_csv('data/house_data.csv',na_values = '暂无资料',index_col = 0)
df.head(3)
# Out:
#                               標題  产权性质  住宅类别 建筑类别  参考月供     年代    建筑面积  \
# 0  急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权  普通住宅   板楼   NaN  1989年   70.40
# 1       世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权  普通住宅   塔楼   NaN  1989年   49.82
# 2              大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN   NaN  2005年  288.30
#
#          户型        楼层      物 业 费 物业类型   结构   装修      總價
# 0  2室2厅1厨1卫   中层(共6层)        NaN   住宅   平层  精装修    30.6
# 1  2室1厅0厨1卫   中层(共6层)    1元/平米・月   住宅   平层  简装修   418.0
# 2  4室2厅0厨2卫  高层(共40层)  3.5元/平米・月   住宅  NaN  精装修  2650.0

# %% [markdown]
# ## 检视后三行资料

# %%
df.tail(3)
# Out:
#                                  標題  产权性质  住宅类别 建筑类别  参考月供     年代    建筑面积  \
# 237  6.12双轨，交通便利，配套成熟，购物方便，房东可接受置换！  个人产权  普通住宅   钢混   NaN  2005年   96.82
# 238       业主二次装修，保养好，户型方正，三房朝南，，随时看  个人产权  普通住宅   板楼   NaN  2002年  168.00
# 239   区进门位置 三街坊43平直套通风一房 一梯二户 房东诚心卖  个人产权  普通住宅   板楼   NaN  1996年   43.13
#
#            户型        楼层       物 业 费 物业类型  结构   装修      總價
# 237  2室2厅1厨1卫   高层(共8层)  1.86元/平米・月   住宅  平层  精装修   460.0
# 238  3室2厅1厨2卫  高层(共20层)     2元/平米・月   住宅  平层  简装修  1250.0
# 239  1室1厅1厨1卫   高层(共7层)   0.3元/平米・月   住宅  平层  简装修   278.0

# %% [markdown]
# ## 检查DataFrame信息

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 240 entries, 0 to 239
# Data columns (total 14 columns):
# 標題       240 non-null object
# 产权性质     228 non-null object
# 住宅类别     218 non-null object
# 建筑类别     188 non-null object
# 参考月供     0 non-null float64
# 年代       224 non-null object
# 建筑面积     240 non-null float64
# 户型       240 non-null object
# 楼层       228 non-null object
# 物 业 费    215 non-null object
# 物业类型     240 non-null object
# 结构       181 non-null object
# 装修       228 non-null object
# 總價       237 non-null float64
# dtypes: float64(3), object(11)
# memory usage: 28.1+ KB

# %% [markdown]
# ## 检查字段名称

# %%
df.columns
# Out:
# Index(['標題', '产权性质', '住宅类别', '建筑类别', '参考月供', '年代', '建筑面积', '户型', '楼层', '物 业 费',
#        '物业类型', '结构', '装修', '總價'],
#       dtype='object')

# %% [markdown]
# ## 检查字段形态

# %%
df.dtypes
# Out:
# 標題        object
# 产权性质      object
# 住宅类别      object
# 建筑类别      object
# 参考月供     float64
# 年代        object
# 建筑面积     float64
# 户型        object
# 楼层        object
# 物 业 费     object
# 物业类型      object
# 结构        object
# 装修        object
# 總價       float64
# dtype: object

# %% [markdown]
# ## 取得叙述性描述

# %%
df.describe()
# Out:
#        参考月供        建筑面积            總價
# count   0.0  240.000000    237.000000
# mean    NaN  113.435333    646.092869
# std     NaN   99.199836   1300.349319
# min     NaN   22.500000     30.600000
# 25%     NaN   68.952500    220.000000
# 50%     NaN   88.155000    400.000000
# 75%     NaN  123.250000    578.000000
# max     NaN  731.240000  11000.000000

# %% [markdown]
# ## 侦查缺失值

# %%
# df.isnull()
df.isnull().any()
# Out:
# 標題       False
# 产权性质      True
# 住宅类别      True
# 建筑类别      True
# 参考月供      True
# 年代        True
# 建筑面积     False
# 户型       False
# 楼层        True
# 物 业 费     True
# 物业类型     False
# 结构        True
# 装修        True
# 總價        True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# 標題         0
# 产权性质      12
# 住宅类别      22
# 建筑类别      52
# 参考月供     240
# 年代        16
# 建筑面积       0
# 户型         0
# 楼层        12
# 物 业 费     25
# 物业类型       0
# 结构        59
# 装修        12
# 總價         3
# dtype: int64

# %%
df.isnull().sum()/df.count()
# Out:
# 標題       0.000000
# 产权性质     0.052632
# 住宅类别     0.100917
# 建筑类别     0.276596
# 参考月供          inf
# 年代       0.071429
# 建筑面积     0.000000
# 户型       0.000000
# 楼层       0.052632
# 物 业 费    0.116279
# 物业类型     0.000000
# 结构       0.325967
# 装修       0.052632
# 總價       0.012658
# dtype: float64

# %% [markdown]
# ## 删除有缺失值的字段

# %%
df.head(3)
# Out:
#                               標題  产权性质  住宅类别 建筑类别  参考月供     年代    建筑面积  \
# 0  急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权  普通住宅   板楼   NaN  1989年   70.40
# 1       世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权  普通住宅   塔楼   NaN  1989年   49.82
# 2              大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN   NaN  2005年  288.30
#
#          户型        楼层      物 业 费 物业类型   结构   装修      總價
# 0  2室2厅1厨1卫   中层(共6层)        NaN   住宅   平层  精装修    30.6
# 1  2室1厅0厨1卫   中层(共6层)    1元/平米・月   住宅   平层  简装修   418.0
# 2  4室2厅0厨2卫  高层(共40层)  3.5元/平米・月   住宅  NaN  精装修  2650.0

# %%
df = df.drop('参考月供',axis = 1)

# %%
df.head(3)
# Out:
#                               標題  产权性质  住宅类别 建筑类别     年代    建筑面积        户型  \
# 0  急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权  普通住宅   板楼  1989年   70.40  2室2厅1厨1卫
# 1       世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权  普通住宅   塔楼  1989年   49.82  2室1厅0厨1卫
# 2              大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN  2005年  288.30  4室2厅0厨2卫
#
#          楼层      物 业 费 物业类型   结构   装修      總價
# 0   中层(共6层)        NaN   住宅   平层  精装修    30.6
# 1   中层(共6层)    1元/平米・月   住宅   平层  简装修   418.0
# 2  高层(共40层)  3.5元/平米・月   住宅  NaN  精装修  2650.0

# %% [markdown]
# ## 筛选字段

# %%
df['产权性质'].value_counts()
# Out:
# 个人产权     171
# 商品房       54
# 经济适用房      2
# 售后公房       1
# Name: 产权性质, dtype: int64

# %%
df[df['产权性质'] == '个人产权'].head(3)
# Out:
#                               標題  产权性质  住宅类别 建筑类别     年代    建筑面积        户型  \
# 0  急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权  普通住宅   板楼  1989年   70.40  2室2厅1厨1卫
# 1       世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权  普通住宅   塔楼  1989年   49.82  2室1厅0厨1卫
# 2              大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN  2005年  288.30  4室2厅0厨2卫
#
#          楼层      物 业 费 物业类型   结构   装修      總價
# 0   中层(共6层)        NaN   住宅   平层  精装修    30.6
# 1   中层(共6层)    1元/平米・月   住宅   平层  简装修   418.0
# 2  高层(共40层)  3.5元/平米・月   住宅  NaN  精装修  2650.0

# %%
df['产权性质'].value_counts()
# Out:
# 个人产权     171
# 商品房       54
# 经济适用房      2
# 售后公房       1
# Name: 产权性质, dtype: int64

# %%
df.iloc[5:7]
# Out:
#                       標題 产权性质 住宅类别 建筑类别     年代   建筑面积        户型       楼层  \
# 5      延吉控江一楼天井精装修水丰南北通透  商品房  NaN   板楼  1986年   35.0  1室2厅1厨1卫  低层(共6层)
# 6  纯双拼别墅，外环旁低总价，奢华大厅，美极了  NaN  NaN  NaN    NaN  237.0  4室3厅1厨4卫      NaN
#
#         物 业 费 物业类型   结构   装修      總價
# 5  0.85元/平米・月   住宅   平层  简装修   205.0
# 6   3.8元/平米・月   别墅  NaN  NaN  1000.0

# %%
df.ix[(df['建筑面积'] > 100) & (df['總價'] > 2000) ,].head(3)
# Out:
# D:\Anaconda3.6.5fille\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#                                    標題  产权性质  住宅类别 建筑类别     年代    建筑面积  \
# 2                   大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN  2005年  288.30
# 11     绿城豪宅，精品纯独栋，格局方正，双南设计，全明通透，豪华气派   NaN   NaN  NaN    NaN  502.00
# 60  华府天地主营专员+价格可谈+1层1户+看房方便+送车位+高区看湖景  个人产权  普通住宅  NaN  2006年  454.82
#
#           户型        楼层       物 业 费 物业类型   结构   装修      總價
# 2   4室2厅0厨2卫  高层(共40层)   3.5元/平米・月   住宅  NaN  精装修  2650.0
# 11  5室3厅2厨6卫       NaN  6.5元/平方米・月   别墅  NaN  NaN  2798.0
# 60  5室3厅2厨4卫  高层(共21层)  14.5元/平米・月   住宅  NaN  精装修  5500.0

# %% [markdown]
# ## 舍弃包含缺失值的字段

# %%
df.head(3)
# Out:
#                               標題  产权性质  住宅类别 建筑类别     年代    建筑面积        户型  \
# 0  急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权  普通住宅   板楼  1989年   70.40  2室2厅1厨1卫
# 1       世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权  普通住宅   塔楼  1989年   49.82  2室1厅0厨1卫
# 2              大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN  2005年  288.30  4室2厅0厨2卫
#
#          楼层      物 业 费 物业类型   结构   装修      總價
# 0   中层(共6层)        NaN   住宅   平层  精装修    30.6
# 1   中层(共6层)    1元/平米・月   住宅   平层  简装修   418.0
# 2  高层(共40层)  3.5元/平米・月   住宅  NaN  精装修  2650.0

# %%
df[df['建筑类别'].isnull()].head(3)
# Out:
#                                 標題  产权性质  住宅类别 建筑类别     年代   建筑面积        户型  \
# 2                大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN  2005年  288.3  4室2厅0厨2卫
# 6            纯双拼别墅，外环旁低总价，奢华大厅，美极了   NaN   NaN  NaN    NaN  237.0  4室3厅1厨4卫
# 11  绿城豪宅，精品纯独栋，格局方正，双南设计，全明通透，豪华气派   NaN   NaN  NaN    NaN  502.0  5室3厅2厨6卫
#
#           楼层       物 业 费 物业类型   结构   装修      總價
# 2   高层(共40层)   3.5元/平米・月   住宅  NaN  精装修  2650.0
# 6        NaN   3.8元/平米・月   别墅  NaN  NaN  1000.0
# 11       NaN  6.5元/平方米・月   别墅  NaN  NaN  2798.0

# %%
df = df.dropna(axis = 1,how = 'all')

# %%
df.head()
# Out:
#                               標題  产权性质  住宅类别 建筑类别     年代    建筑面积        户型  \
# 0  急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权  普通住宅   板楼  1989年   70.40  2室2厅1厨1卫
# 1       世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权  普通住宅   塔楼  1989年   49.82  2室1厅0厨1卫
# 2              大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN  2005年  288.30  4室2厅0厨2卫
# 3       精装二房全明户型户型好客厅主卧朝南带阳台看房方便   商品房   NaN   板楼  1994年   56.00  2室1厅1厨1卫
# 4   满五税费少,房东接受置换客户,房东这边房子已经看好,急卖  个人产权  普通住宅   钢混  1998年   58.00  2室1厅1厨1卫
#
#          楼层      物 业 费 物业类型   结构   装修      總價
# 0   中层(共6层)        NaN   住宅   平层  精装修    30.6
# 1   中层(共6层)    1元/平米・月   住宅   平层  简装修   418.0
# 2  高层(共40层)  3.5元/平米・月   住宅  NaN  精装修  2650.0
# 3   高层(共6层)  0.4元/平米・月   住宅   平层  简装修   280.0
# 4   高层(共6层)  0.4元/平米・月   住宅   平层  精装修   190.0

# %% [markdown]
# ## 补齐缺失值

# %%
df.head(3)
# Out:
#                               標題  产权性质  住宅类别 建筑类别     年代    建筑面积        户型  \
# 0  急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权  普通住宅   板楼  1989年   70.40  2室2厅1厨1卫
# 1       世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权  普通住宅   塔楼  1989年   49.82  2室1厅0厨1卫
# 2              大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN  2005年  288.30  4室2厅0厨2卫
#
#          楼层      物 业 费 物业类型   结构   装修      總價
# 0   中层(共6层)        NaN   住宅   平层  精装修    30.6
# 1   中层(共6层)    1元/平米・月   住宅   平层  简装修   418.0
# 2  高层(共40层)  3.5元/平米・月   住宅  NaN  精装修  2650.0

# %%
df['物 业 费'] = df['物 业 费'].fillna(0)

# %%
df.head(3)
# Out:
#                               標題  产权性质  住宅类别 建筑类别     年代    建筑面积        户型  \
# 0  急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权  普通住宅   板楼  1989年   70.40  2室2厅1厨1卫
# 1       世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权  普通住宅   塔楼  1989年   49.82  2室1厅0厨1卫
# 2              大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN  2005年  288.30  4室2厅0厨2卫
#
#          楼层      物 业 费 物业类型   结构   装修      總價
# 0   中层(共6层)          0   住宅   平层  精装修    30.6
# 1   中层(共6层)    1元/平米・月   住宅   平层  简装修   418.0
# 2  高层(共40层)  3.5元/平米・月   住宅  NaN  精装修  2650.0

# %%
df['總價'].isnull().sum()
# Out:
# 3

# %%
df[df['總價'].isnull()]
# Out:
#                                標題  产权性质  住宅类别 建筑类别     年代   建筑面积        户型  \
# 18   光新路191弄 南北通透两室户 地段佳 出行方便满五少税  个人产权  普通住宅   板楼  1990年  47.00  2室1厅1厨1卫
# 160         周边六所 高铁旁 风景边 别墅生活圈 户型   商品房  普通住宅   钢混  2013年  90.00  3室1厅1厨1卫
# 175                     精品好房 稍纵即逝  个人产权  普通住宅   钢混  2014年  99.38  3室2厅1厨2卫
#
#            楼层      物 业 费 物业类型  结构    装修  總價
# 18    低层(共6层)  0.3元/平米・月   住宅  平层   精装修 NaN
# 160  中层(共18层)          0   住宅  平层  豪华装修 NaN
# 175  中层(共11层)   1.95元/・月   住宅  平层   精装修 NaN

# %%
(df['總價'] / df['建筑面积']).mean()
# Out:
# 4.680711101665693

# %%
df['總價'].isnull().sum()
# Out:
# 3

# %%
df['總價'] = df['總價'].fillna(df['建筑面积'] * (df['總價'] / df['建筑面积']).mean())

# %%
df['總價'].isnull().sum()
# Out:
# 0

# %%
df.head()
# Out:
#                               標題  产权性质  住宅类别 建筑类别     年代    建筑面积        户型  \
# 0  急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权  普通住宅   板楼  1989年   70.40  2室2厅1厨1卫
# 1       世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权  普通住宅   塔楼  1989年   49.82  2室1厅0厨1卫
# 2              大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN  2005年  288.30  4室2厅0厨2卫
# 3       精装二房全明户型户型好客厅主卧朝南带阳台看房方便   商品房   NaN   板楼  1994年   56.00  2室1厅1厨1卫
# 4   满五税费少,房东接受置换客户,房东这边房子已经看好,急卖  个人产权  普通住宅   钢混  1998年   58.00  2室1厅1厨1卫
#
#          楼层      物 业 费 物业类型   结构   装修      總價
# 0   中层(共6层)          0   住宅   平层  精装修    30.6
# 1   中层(共6层)    1元/平米・月   住宅   平层  简装修   418.0
# 2  高层(共40层)  3.5元/平米・月   住宅  NaN  精装修  2650.0
# 3   高层(共6层)  0.4元/平米・月   住宅   平层  简装修   280.0
# 4   高层(共6层)  0.4元/平米・月   住宅   平层  精装修   190.0

# %% [markdown]
# ## 将资料写入csv中

# %%
df.to_csv('house_final.csv',index_label = False)
