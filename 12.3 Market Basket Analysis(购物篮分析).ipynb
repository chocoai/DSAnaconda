# %% [markdown]
# ## 读取交易数据

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('Data\Market_Basket.csv', header = None)
df.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# 0  low fat yogurt  green tea  honey  salad  mineral water  salmon
# 1             NaN        NaN    NaN    NaN            NaN     NaN
# 2             NaN        NaN    NaN    NaN            NaN     NaN
# 3             NaN        NaN    NaN    NaN            NaN     NaN
# 4             NaN        NaN    NaN    NaN            NaN     NaN
#
#                   16               17       18         19
# 0  antioxydant juice  frozen smoothie  spinach  olive oil
# 1                NaN              NaN      NaN        NaN
# 2                NaN              NaN      NaN        NaN
# 3                NaN              NaN      NaN        NaN
# 4                NaN              NaN      NaN        NaN

# %%
df.count()
# Out:
# 0     7501
# 1     5747
# 2     4389
# 3     3345
# 4     2529
# 5     1864
# 6     1369
# 7      981
# 8      654
# 9      395
# 10     256
# 11     154
# 12      87
# 13      47
# 14      25
# 15       8
# 16       4
# 17       4
# 18       3
# 19       1
# dtype: int64

# %% [markdown]
# ## 增添交易记录

# %%
transactions = []
for i in range(0, 7501):
    transactions.append([str(df.values[i,j]) for j in range(0, 20)])

# %%
# transactions[1]

# %% [markdown]
# ## 使用Apriori产生关联预测

# %%
from apyori import apriori
rules = apriori(transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2)

# Visualising the results
results = list(rules)

# %%
results[0]
# Out:
# RelationRecord(items=frozenset({'light cream', 'chicken'}), support=0.004532728969470737, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light cream'}), items_add=frozenset({'chicken'}), confidence=0.29059829059829057, lift=4.84395061728395)])

# %% [markdown]
# ## 产生关联规则

# %%
for rec in results:
    left_hands = rec.ordered_statistics[0].items_base
    right_hands = rec.ordered_statistics[0].items_add
    l = ';'.join([item for item in left_hands])
    r = ';'.join([item for item in right_hands])
    print('{} => {}'.format(l,r))
# Out:
# light cream => chicken
# mushroom cream sauce => escalope
# pasta => escalope
# fromage blanc => honey
# herb & pepper => ground beef
# tomato sauce => ground beef
# light cream => olive oil
# whole wheat pasta => olive oil
# pasta => shrimp
# spaghetti;avocado => milk
# cake;milk => burgers
# turkey;chocolate => burgers
# turkey;milk => burgers
# frozen vegetables;cake => tomatoes
# cereals;ground beef => spaghetti
# ground beef;chicken => milk
# light cream;nan => chicken
# milk;chicken => olive oil
# spaghetti;chicken => olive oil
# frozen vegetables;chocolate => shrimp
# herb & pepper;chocolate => ground beef
# soup;chocolate => milk
# cooking oil;ground beef => spaghetti
# ground beef;eggs => herb & pepper
# eggs;red wine => spaghetti
# nan;mushroom cream sauce => escalope
# pasta;nan => escalope
# french fries;ground beef => herb & pepper
# fromage blanc;nan => honey
# frozen vegetables;green tea => tomatoes
# frozen vegetables;spaghetti => ground beef
# frozen vegetables;milk => olive oil
# frozen vegetables;soup => milk
# milk;tomatoes => frozen vegetables
# shrimp;mineral water => frozen vegetables
# frozen vegetables;spaghetti => olive oil
# frozen vegetables;spaghetti => shrimp
# frozen vegetables;shrimp => tomatoes
# frozen vegetables;spaghetti => tomatoes
# grated cheese;spaghetti => ground beef
# green tea;ground beef => tomatoes
# herb & pepper;milk => ground beef
# mineral water;herb & pepper => ground beef
# herb & pepper;nan => ground beef
# herb & pepper;spaghetti => ground beef
# ground beef;milk => olive oil
# ground beef;soup => milk
# tomato sauce;nan => ground beef
# pepper;spaghetti => ground beef
# shrimp;ground beef => spaghetti
# tomato sauce;ground beef => spaghetti
# light cream;nan => olive oil
# shrimp;olive oil => milk
# olive oil;milk => soup
# spaghetti;milk => olive oil
# milk;tomatoes => soup
# whole wheat pasta;spaghetti => milk
# mineral water;soup => olive oil
# whole wheat pasta;mineral water => olive oil
# whole wheat pasta;nan => olive oil
# pasta;nan => shrimp
# pancakes;spaghetti => olive oil
# olive oil;tomatoes => spaghetti
# spaghetti;whole wheat rice => tomatoes
# spaghetti;nan;avocado => milk
# nan;cake;milk => burgers
# turkey;chocolate;nan => burgers
# turkey;nan;milk => burgers
# frozen vegetables;cake;nan => tomatoes
# cereals;ground beef;nan => spaghetti
# ground beef;nan;chicken => milk
# nan;milk;chicken => olive oil
# spaghetti;nan;chicken => olive oil
# mineral water;eggs;chocolate => ground beef
# frozen vegetables;mineral water;chocolate => ground beef
# frozen vegetables;ground beef;chocolate => spaghetti
# frozen vegetables;mineral water;chocolate => milk
# frozen vegetables;spaghetti;chocolate => milk
# frozen vegetables;mineral water;chocolate => shrimp
# frozen vegetables;chocolate;nan => shrimp
# herb & pepper;chocolate;nan => ground beef
# soup;chocolate;nan => milk
# mineral water;spaghetti;chocolate => olive oil
# mineral water;spaghetti;chocolate => shrimp
# cooking oil;ground beef;nan => spaghetti
# frozen vegetables;mineral water;eggs => milk
# ground beef;eggs;nan => herb & pepper
# eggs;nan;red wine => spaghetti
# french fries;ground beef;nan => herb & pepper
# frozen smoothie;mineral water;spaghetti => milk
# frozen vegetables;green tea;nan => tomatoes
# frozen vegetables;mineral water;ground beef => milk
# frozen vegetables;ground beef;milk => spaghetti
# frozen vegetables;mineral water;spaghetti => ground beef
# frozen vegetables;spaghetti;nan => ground beef
# frozen vegetables;mineral water;milk => olive oil
# frozen vegetables;mineral water;milk => soup
# mineral water;spaghetti;milk => frozen vegetables
# frozen vegetables;nan;milk => olive oil
# frozen vegetables;soup;nan => milk
# nan;milk;tomatoes => frozen vegetables
# shrimp;mineral water;nan => frozen vegetables
# frozen vegetables;mineral water;spaghetti => shrimp
# frozen vegetables;mineral water;spaghetti => tomatoes
# frozen vegetables;spaghetti;nan => olive oil
# frozen vegetables;spaghetti;nan => shrimp
# frozen vegetables;shrimp;nan => tomatoes
# frozen vegetables;spaghetti;nan => tomatoes
# grated cheese;spaghetti;nan => ground beef
# green tea;ground beef;nan => tomatoes
# herb & pepper;nan;milk => ground beef
# mineral water;herb & pepper;nan => ground beef
# herb & pepper;spaghetti;nan => ground beef
# ground beef;nan;milk => olive oil
# ground beef;soup;nan => milk
# olive oil;mineral water;spaghetti => ground beef
# mineral water;ground beef;tomatoes => spaghetti
# pepper;spaghetti;nan => ground beef
# shrimp;ground beef;nan => spaghetti
# tomato sauce;ground beef;nan => spaghetti
# mineral water;spaghetti;milk => olive oil
# mineral water;spaghetti;milk => tomatoes
# shrimp;olive oil;nan => milk
# olive oil;nan;milk => soup
# spaghetti;nan;milk => olive oil
# nan;milk;tomatoes => soup
# whole wheat pasta;spaghetti;nan => milk
# mineral water;soup;nan => olive oil
# whole wheat pasta;mineral water;nan => olive oil
# pancakes;spaghetti;nan => olive oil
# olive oil;nan;tomatoes => spaghetti
# whole wheat rice;spaghetti;nan => tomatoes
# mineral water;eggs;chocolate;nan => ground beef
# frozen vegetables;mineral water;chocolate;nan => ground beef
# frozen vegetables;ground beef;chocolate;nan => spaghetti
# frozen vegetables;mineral water;chocolate;nan => milk
# frozen vegetables;spaghetti;chocolate;nan => milk
# frozen vegetables;mineral water;chocolate;nan => shrimp
# mineral water;spaghetti;chocolate;nan => olive oil
# mineral water;spaghetti;chocolate;nan => shrimp
# frozen vegetables;mineral water;eggs;nan => milk
# frozen smoothie;mineral water;spaghetti;nan => milk
# frozen vegetables;mineral water;ground beef;nan => milk
# frozen vegetables;ground beef;nan;milk => spaghetti
# frozen vegetables;mineral water;spaghetti;nan => ground beef
# frozen vegetables;mineral water;nan;milk => olive oil
# frozen vegetables;mineral water;nan;milk => soup
# mineral water;spaghetti;nan;milk => frozen vegetables
# frozen vegetables;mineral water;spaghetti;nan => shrimp
# frozen vegetables;mineral water;spaghetti;nan => tomatoes
# olive oil;mineral water;spaghetti;nan => ground beef
# mineral water;ground beef;nan;tomatoes => spaghetti
# mineral water;spaghetti;nan;milk => olive oil
# mineral water;spaghetti;nan;milk => tomatoes

# %% [markdown]
# ## 产生频繁交易集

# %%
import itertools
for ele in itertools.combinations(['milk', 'spaghetti', 'avocado'], 2):
    print(ele)
# Out:
# ('milk', 'spaghetti')
# ('milk', 'avocado')
# ('spaghetti', 'avocado')

# %%
itemsets = []
for rec in results:    
    #print(rec.items)
    for ele in itertools.combinations(rec.items, 2):
        itemsets.append(ele)

# %%
itemsets
# Out:
# [('light cream', 'chicken'),
#  ('escalope', 'mushroom cream sauce'),
#  ('escalope', 'pasta'),
#  ('fromage blanc', 'honey'),
#  ('herb & pepper', 'ground beef'),
#  ('tomato sauce', 'ground beef'),
#  ('olive oil', 'light cream'),
#  ('whole wheat pasta', 'olive oil'),
#  ('shrimp', 'pasta'),
#  ('spaghetti', 'milk'),
#  ('spaghetti', 'avocado'),
#  ('milk', 'avocado'),
#  ('burgers', 'cake'),
#  ('burgers', 'milk'),
#  ('cake', 'milk'),
#  ('burgers', 'turkey'),
#  ('burgers', 'chocolate'),
#  ('turkey', 'chocolate'),
#  ('burgers', 'turkey'),
#  ('burgers', 'milk'),
#  ('turkey', 'milk'),
#  ('frozen vegetables', 'cake'),
#  ('frozen vegetables', 'tomatoes'),
#  ('cake', 'tomatoes'),
#  ('cereals', 'ground beef'),
#  ('cereals', 'spaghetti'),
#  ('ground beef', 'spaghetti'),
#  ('ground beef', 'milk'),
#  ('ground beef', 'chicken'),
#  ('milk', 'chicken'),
#  ('light cream', 'nan'),
#  ('light cream', 'chicken'),
#  ('nan', 'chicken'),
#  ('olive oil', 'milk'),
#  ('olive oil', 'chicken'),
#  ('milk', 'chicken'),
#  ('olive oil', 'spaghetti'),
#  ('olive oil', 'chicken'),
#  ('spaghetti', 'chicken'),
#  ('shrimp', 'frozen vegetables'),
#  ('shrimp', 'chocolate'),
#  ('frozen vegetables', 'chocolate'),
#  ('herb & pepper', 'ground beef'),
#  ('herb & pepper', 'chocolate'),
#  ('ground beef', 'chocolate'),
#  ('soup', 'chocolate'),
#  ('soup', 'milk'),
#  ('chocolate', 'milk'),
#  ('cooking oil', 'ground beef'),
#  ('cooking oil', 'spaghetti'),
#  ('ground beef', 'spaghetti'),
#  ('herb & pepper', 'ground beef'),
#  ('herb & pepper', 'eggs'),
#  ('ground beef', 'eggs'),
#  ('eggs', 'spaghetti'),
#  ('eggs', 'red wine'),
#  ('spaghetti', 'red wine'),
#  ('escalope', 'nan'),
#  ('escalope', 'mushroom cream sauce'),
#  ('nan', 'mushroom cream sauce'),
#  ('escalope', 'pasta'),
#  ('escalope', 'nan'),
#  ('pasta', 'nan'),
#  ('french fries', 'ground beef'),
#  ('french fries', 'herb & pepper'),
#  ('ground beef', 'herb & pepper'),
#  ('fromage blanc', 'honey'),
#  ('fromage blanc', 'nan'),
#  ('honey', 'nan'),
#  ('frozen vegetables', 'green tea'),
#  ('frozen vegetables', 'tomatoes'),
#  ('green tea', 'tomatoes'),
#  ('frozen vegetables', 'ground beef'),
#  ('frozen vegetables', 'spaghetti'),
#  ('ground beef', 'spaghetti'),
#  ('frozen vegetables', 'olive oil'),
#  ('frozen vegetables', 'milk'),
#  ('olive oil', 'milk'),
#  ('frozen vegetables', 'soup'),
#  ('frozen vegetables', 'milk'),
#  ('soup', 'milk'),
#  ('frozen vegetables', 'milk'),
#  ('frozen vegetables', 'tomatoes'),
#  ('milk', 'tomatoes'),
#  ('frozen vegetables', 'mineral water'),
#  ('frozen vegetables', 'shrimp'),
#  ('mineral water', 'shrimp'),
#  ('frozen vegetables', 'olive oil'),
#  ('frozen vegetables', 'spaghetti'),
#  ('olive oil', 'spaghetti'),
#  ('frozen vegetables', 'spaghetti'),
#  ('frozen vegetables', 'shrimp'),
#  ('spaghetti', 'shrimp'),
#  ('frozen vegetables', 'shrimp'),
#  ('frozen vegetables', 'tomatoes'),
#  ('shrimp', 'tomatoes'),
#  ('frozen vegetables', 'spaghetti'),
#  ('frozen vegetables', 'tomatoes'),
#  ('spaghetti', 'tomatoes'),
#  ('grated cheese', 'ground beef'),
#  ('grated cheese', 'spaghetti'),
#  ('ground beef', 'spaghetti'),
#  ('green tea', 'ground beef'),
#  ('green tea', 'tomatoes'),
#  ('ground beef', 'tomatoes'),
#  ('herb & pepper', 'ground beef'),
#  ('herb & pepper', 'milk'),
#  ('ground beef', 'milk'),
#  ('herb & pepper', 'mineral water'),
#  ('herb & pepper', 'ground beef'),
#  ('mineral water', 'ground beef'),
#  ('herb & pepper', 'ground beef'),
#  ('herb & pepper', 'nan'),
#  ('ground beef', 'nan'),
#  ('herb & pepper', 'ground beef'),
#  ('herb & pepper', 'spaghetti'),
#  ('ground beef', 'spaghetti'),
#  ('olive oil', 'ground beef'),
#  ('olive oil', 'milk'),
#  ('ground beef', 'milk'),
#  ('ground beef', 'soup'),
#  ('ground beef', 'milk'),
#  ('soup', 'milk'),
#  ('tomato sauce', 'ground beef'),
#  ('tomato sauce', 'nan'),
#  ('ground beef', 'nan'),
#  ('pepper', 'ground beef'),
#  ('pepper', 'spaghetti'),
#  ('ground beef', 'spaghetti'),
#  ('shrimp', 'ground beef'),
#  ('shrimp', 'spaghetti'),
#  ('ground beef', 'spaghetti'),
#  ('tomato sauce', 'ground beef'),
#  ('tomato sauce', 'spaghetti'),
#  ('ground beef', 'spaghetti'),
#  ('olive oil', 'light cream'),
#  ('olive oil', 'nan'),
#  ('light cream', 'nan'),
#  ('shrimp', 'olive oil'),
#  ('shrimp', 'milk'),
#  ('olive oil', 'milk'),
#  ('olive oil', 'soup'),
#  ('olive oil', 'milk'),
#  ('soup', 'milk'),
#  ('olive oil', 'spaghetti'),
#  ('olive oil', 'milk'),
#  ('spaghetti', 'milk'),
#  ('soup', 'milk'),
#  ('soup', 'tomatoes'),
#  ('milk', 'tomatoes'),
#  ('whole wheat pasta', 'spaghetti'),
#  ('whole wheat pasta', 'milk'),
#  ('spaghetti', 'milk'),
#  ('olive oil', 'mineral water'),
#  ('olive oil', 'soup'),
#  ('mineral water', 'soup'),
#  ('whole wheat pasta', 'olive oil'),
#  ('whole wheat pasta', 'mineral water'),
#  ('olive oil', 'mineral water'),
#  ('whole wheat pasta', 'olive oil'),
#  ('whole wheat pasta', 'nan'),
#  ('olive oil', 'nan'),
#  ('shrimp', 'pasta'),
#  ('shrimp', 'nan'),
#  ('pasta', 'nan'),
#  ('pancakes', 'olive oil'),
#  ('pancakes', 'spaghetti'),
#  ('olive oil', 'spaghetti'),
#  ('olive oil', 'spaghetti'),
#  ('olive oil', 'tomatoes'),
#  ('spaghetti', 'tomatoes'),
#  ('spaghetti', 'whole wheat rice'),
#  ('spaghetti', 'tomatoes'),
#  ('whole wheat rice', 'tomatoes'),
#  ('spaghetti', 'nan'),
#  ('spaghetti', 'milk'),
#  ('spaghetti', 'avocado'),
#  ('nan', 'milk'),
#  ('nan', 'avocado'),
#  ('milk', 'avocado'),
#  ('burgers', 'nan'),
#  ('burgers', 'cake'),
#  ('burgers', 'milk'),
#  ('nan', 'cake'),
#  ('nan', 'milk'),
#  ('cake', 'milk'),
#  ('burgers', 'turkey'),
#  ('burgers', 'chocolate'),
#  ('burgers', 'nan'),
#  ('turkey', 'chocolate'),
#  ('turkey', 'nan'),
#  ('chocolate', 'nan'),
#  ('burgers', 'turkey'),
#  ('burgers', 'nan'),
#  ('burgers', 'milk'),
#  ('turkey', 'nan'),
#  ('turkey', 'milk'),
#  ('nan', 'milk'),
#  ('frozen vegetables', 'cake'),
#  ('frozen vegetables', 'nan'),
#  ('frozen vegetables', 'tomatoes'),
#  ('cake', 'nan'),
#  ('cake', 'tomatoes'),
#  ('nan', 'tomatoes'),
#  ('cereals', 'ground beef'),
#  ('cereals', 'spaghetti'),
#  ('cereals', 'nan'),
#  ('ground beef', 'spaghetti'),
#  ('ground beef', 'nan'),
#  ('spaghetti', 'nan'),
#  ('ground beef', 'nan'),
#  ('ground beef', 'milk'),
#  ('ground beef', 'chicken'),
#  ('nan', 'milk'),
#  ('nan', 'chicken'),
#  ('milk', 'chicken'),
#  ('olive oil', 'nan'),
#  ('olive oil', 'milk'),
#  ('olive oil', 'chicken'),
#  ('nan', 'milk'),
#  ('nan', 'chicken'),
#  ('milk', 'chicken'),
#  ('olive oil', 'spaghetti'),
#  ('olive oil', 'nan'),
#  ('olive oil', 'chicken'),
#  ('spaghetti', 'nan'),
#  ('spaghetti', 'chicken'),
#  ('nan', 'chicken'),
#  ('ground beef', 'mineral water'),
#  ('ground beef', 'eggs'),
#  ('ground beef', 'chocolate'),
#  ('mineral water', 'eggs'),
#  ('mineral water', 'chocolate'),
#  ('eggs', 'chocolate'),
#  ('frozen vegetables', 'mineral water'),
#  ('frozen vegetables', 'ground beef'),
#  ('frozen vegetables', 'chocolate'),
#  ('mineral water', 'ground beef'),
#  ('mineral water', 'chocolate'),
#  ('ground beef', 'chocolate'),
#  ('frozen vegetables', 'spaghetti'),
#  ('frozen vegetables', 'ground beef'),
#  ('frozen vegetables', 'chocolate'),
#  ('spaghetti', 'ground beef'),
#  ('spaghetti', 'chocolate'),
#  ('ground beef', 'chocolate'),
#  ('frozen vegetables', 'mineral water'),
#  ('frozen vegetables', 'chocolate'),
#  ('frozen vegetables', 'milk'),
#  ('mineral water', 'chocolate'),
#  ('mineral water', 'milk'),
#  ('chocolate', 'milk'),
#  ('frozen vegetables', 'spaghetti'),
#  ('frozen vegetables', 'chocolate'),
#  ('frozen vegetables', 'milk'),
#  ('spaghetti', 'chocolate'),
#  ('spaghetti', 'milk'),
#  ('chocolate', 'milk'),
#  ('shrimp', 'frozen vegetables'),
#  ('shrimp', 'mineral water'),
#  ('shrimp', 'chocolate'),
#  ('frozen vegetables', 'mineral water'),
#  ('frozen vegetables', 'chocolate'),
#  ('mineral water', 'chocolate'),
#  ('shrimp', 'frozen vegetables'),
#  ('shrimp', 'chocolate'),
#  ('shrimp', 'nan'),
#  ('frozen vegetables', 'chocolate'),
#  ('frozen vegetables', 'nan'),
#  ('chocolate', 'nan'),
#  ('herb & pepper', 'ground beef'),
#  ('herb & pepper', 'chocolate'),
#  ('herb & pepper', 'nan'),
#  ('ground beef', 'chocolate'),
#  ('ground beef', 'nan'),
#  ('chocolate', 'nan'),
#  ('nan', 'soup'),
#  ('nan', 'chocolate'),
#  ('nan', 'milk'),
#  ('soup', 'chocolate'),
#  ('soup', 'milk'),
#  ('chocolate', 'milk'),
#  ('olive oil', 'mineral water'),
#  ('olive oil', 'spaghetti'),
#  ('olive oil', 'chocolate'),
#  ('mineral water', 'spaghetti'),
#  ('mineral water', 'chocolate'),
#  ('spaghetti', 'chocolate'),
#  ('shrimp', 'mineral water'),
#  ('shrimp', 'spaghetti'),
#  ('shrimp', 'chocolate'),
#  ('mineral water', 'spaghetti'),
#  ('mineral water', 'chocolate'),
#  ('spaghetti', 'chocolate'),
#  ('cooking oil', 'ground beef'),
#  ('cooking oil', 'spaghetti'),
#  ('cooking oil', 'nan'),
#  ('ground beef', 'spaghetti'),
#  ('ground beef', 'nan'),
#  ('spaghetti', 'nan'),
#  ('frozen vegetables', 'mineral water'),
#  ('frozen vegetables', 'eggs'),
#  ('frozen vegetables', 'milk'),
#  ('mineral water', 'eggs'),
#  ('mineral water', 'milk'),
#  ('eggs', 'milk'),
#  ('herb & pepper', 'ground beef'),
#  ('herb & pepper', 'eggs'),
#  ('herb & pepper', 'nan'),
#  ('ground beef', 'eggs'),
#  ('ground beef', 'nan'),
#  ('eggs', 'nan'),
#  ('eggs', 'spaghetti'),
#  ('eggs', 'nan'),
#  ('eggs', 'red wine'),
#  ('spaghetti', 'nan'),
#  ('spaghetti', 'red wine'),
#  ('nan', 'red wine'),
#  ('french fries', 'ground beef'),
#  ('french fries', 'nan'),
#  ('french fries', 'herb & pepper'),
#  ('ground beef', 'nan'),
#  ('ground beef', 'herb & pepper'),
#  ('nan', 'herb & pepper'),
#  ('frozen smoothie', 'mineral water'),
#  ('frozen smoothie', 'spaghetti'),
#  ('frozen smoothie', 'milk'),
#  ('mineral water', 'spaghetti'),
#  ('mineral water', 'milk'),
#  ('spaghetti', 'milk'),
#  ('frozen vegetables', 'green tea'),
#  ('frozen vegetables', 'nan'),
#  ('frozen vegetables', 'tomatoes'),
#  ('green tea', 'nan'),
#  ('green tea', 'tomatoes'),
#  ('nan', 'tomatoes'),
#  ('frozen vegetables', 'mineral water'),
#  ('frozen vegetables', 'ground beef'),
#  ('frozen vegetables', 'milk'),
#  ('mineral water', 'ground beef'),
#  ('mineral water', 'milk'),
#  ('ground beef', 'milk'),
#  ('frozen vegetables', 'ground beef'),
#  ('frozen vegetables', 'spaghetti'),
#  ('frozen vegetables', 'milk'),
#  ('ground beef', 'spaghetti'),
#  ('ground beef', 'milk'),
#  ('spaghetti', 'milk'),
#  ('frozen vegetables', 'mineral water'),
#  ('frozen vegetables', 'ground beef'),
#  ('frozen vegetables', 'spaghetti'),
#  ('mineral water', 'ground beef'),
#  ('mineral water', 'spaghetti'),
#  ('ground beef', 'spaghetti'),
#  ('frozen vegetables', 'ground beef'),
#  ('frozen vegetables', 'spaghetti'),
#  ('frozen vegetables', 'nan'),
#  ('ground beef', 'spaghetti'),
#  ('ground beef', 'nan'),
#  ('spaghetti', 'nan'),
#  ('frozen vegetables', 'olive oil'),
#  ('frozen vegetables', 'mineral water'),
#  ('frozen vegetables', 'milk'),
#  ('olive oil', 'mineral water'),
#  ('olive oil', 'milk'),
#  ('mineral water', 'milk'),
#  ('frozen vegetables', 'mineral water'),
#  ('frozen vegetables', 'soup'),
#  ('frozen vegetables', 'milk'),
#  ('mineral water', 'soup'),
#  ('mineral water', 'milk'),
#  ('soup', 'milk'),
#  ('frozen vegetables', 'mineral water'),
#  ('frozen vegetables', 'spaghetti'),
#  ('frozen vegetables', 'milk'),
#  ('mineral water', 'spaghetti'),
#  ('mineral water', 'milk'),
#  ('spaghetti', 'milk'),
#  ('frozen vegetables', 'olive oil'),
#  ('frozen vegetables', 'nan'),
#  ('frozen vegetables', 'milk'),
#  ('olive oil', 'nan'),
#  ('olive oil', 'milk'),
#  ('nan', 'milk'),
#  ('frozen vegetables', 'soup'),
#  ('frozen vegetables', 'nan'),
#  ('frozen vegetables', 'milk'),
#  ('soup', 'nan'),
#  ('soup', 'milk'),
#  ('nan', 'milk'),
#  ('frozen vegetables', 'nan'),
#  ('frozen vegetables', 'milk'),
#  ('frozen vegetables', 'tomatoes'),
#  ('nan', 'milk'),
#  ('nan', 'tomatoes'),
#  ('milk', 'tomatoes'),
#  ('frozen vegetables', 'mineral water'),
#  ('frozen vegetables', 'shrimp'),
#  ('frozen vegetables', 'nan'),
#  ('mineral water', 'shrimp'),
#  ('mineral water', 'nan'),
#  ('shrimp', 'nan'),
#  ('frozen vegetables', 'mineral water'),
#  ('frozen vegetables', 'spaghetti'),
#  ('frozen vegetables', 'shrimp'),
#  ('mineral water', 'spaghetti'),
#  ('mineral water', 'shrimp'),
#  ('spaghetti', 'shrimp'),
#  ('frozen vegetables', 'mineral water'),
#  ('frozen vegetables', 'spaghetti'),
#  ('frozen vegetables', 'tomatoes'),
#  ('mineral water', 'spaghetti'),
#  ('mineral water', 'tomatoes'),
#  ('spaghetti', 'tomatoes'),
#  ('frozen vegetables', 'olive oil'),
#  ('frozen vegetables', 'spaghetti'),
#  ('frozen vegetables', 'nan'),
#  ('olive oil', 'spaghetti'),
#  ('olive oil', 'nan'),
#  ('spaghetti', 'nan'),
#  ('frozen vegetables', 'spaghetti'),
#  ('frozen vegetables', 'shrimp'),
#  ('frozen vegetables', 'nan'),
#  ('spaghetti', 'shrimp'),
#  ('spaghetti', 'nan'),
#  ('shrimp', 'nan'),
#  ('frozen vegetables', 'shrimp'),
#  ('frozen vegetables', 'nan'),
#  ('frozen vegetables', 'tomatoes'),
#  ('shrimp', 'nan'),
#  ('shrimp', 'tomatoes'),
#  ('nan', 'tomatoes'),
#  ('frozen vegetables', 'spaghetti'),
#  ('frozen vegetables', 'nan'),
#  ('frozen vegetables', 'tomatoes'),
#  ('spaghetti', 'nan'),
#  ('spaghetti', 'tomatoes'),
#  ('nan', 'tomatoes'),
#  ('grated cheese', 'ground beef'),
#  ('grated cheese', 'spaghetti'),
#  ('grated cheese', 'nan'),
#  ('ground beef', 'spaghetti'),
#  ('ground beef', 'nan'),
#  ('spaghetti', 'nan'),
#  ('green tea', 'ground beef'),
#  ('green tea', 'nan'),
#  ('green tea', 'tomatoes'),
#  ('ground beef', 'nan'),
#  ('ground beef', 'tomatoes'),
#  ('nan', 'tomatoes'),
#  ('herb & pepper', 'ground beef'),
#  ('herb & pepper', 'nan'),
#  ('herb & pepper', 'milk'),
#  ('ground beef', 'nan'),
#  ('ground beef', 'milk'),
#  ('nan', 'milk'),
#  ('herb & pepper', 'mineral water'),
#  ('herb & pepper', 'ground beef'),
#  ('herb & pepper', 'nan'),
#  ('mineral water', 'ground beef'),
#  ('mineral water', 'nan'),
#  ('ground beef', 'nan'),
#  ('herb & pepper', 'ground beef'),
#  ('herb & pepper', 'spaghetti'),
#  ('herb & pepper', 'nan'),
#  ('ground beef', 'spaghetti'),
#  ('ground beef', 'nan'),
#  ('spaghetti', 'nan'),
#  ('olive oil', 'ground beef'),
#  ('olive oil', 'nan'),
#  ('olive oil', 'milk'),
#  ('ground beef', 'nan'),
#  ('ground beef', 'milk'),
#  ('nan', 'milk'),
#  ('ground beef', 'nan'),
#  ('ground beef', 'milk'),
#  ('ground beef', 'soup'),
#  ('nan', 'milk'),
#  ('nan', 'soup'),
#  ('milk', 'soup'),
#  ('olive oil', 'mineral water'),
#  ('olive oil', 'ground beef'),
#  ('olive oil', 'spaghetti'),
#  ('mineral water', 'ground beef'),
#  ('mineral water', 'spaghetti'),
#  ('ground beef', 'spaghetti'),
#  ('mineral water', 'ground beef'),
#  ('mineral water', 'spaghetti'),
#  ('mineral water', 'tomatoes'),
#  ('ground beef', 'spaghetti'),
#  ('ground beef', 'tomatoes'),
#  ('spaghetti', 'tomatoes'),
#  ('pepper', 'ground beef'),
#  ('pepper', 'spaghetti'),
#  ('pepper', 'nan'),
#  ('ground beef', 'spaghetti'),
#  ('ground beef', 'nan'),
#  ('spaghetti', 'nan'),
#  ('shrimp', 'ground beef'),
#  ('shrimp', 'spaghetti'),
#  ('shrimp', 'nan'),
#  ('ground beef', 'spaghetti'),
#  ('ground beef', 'nan'),
#  ('spaghetti', 'nan'),
#  ('tomato sauce', 'ground beef'),
#  ('tomato sauce', 'spaghetti'),
#  ('tomato sauce', 'nan'),
#  ('ground beef', 'spaghetti'),
#  ('ground beef', 'nan'),
#  ('spaghetti', 'nan'),
#  ('olive oil', 'mineral water'),
#  ('olive oil', 'spaghetti'),
#  ('olive oil', 'milk'),
#  ('mineral water', 'spaghetti'),
#  ('mineral water', 'milk'),
#  ('spaghetti', 'milk'),
#  ('mineral water', 'spaghetti'),
#  ('mineral water', 'milk'),
#  ('mineral water', 'tomatoes'),
#  ('spaghetti', 'milk'),
#  ('spaghetti', 'tomatoes'),
#  ('milk', 'tomatoes'),
#  ('shrimp', 'olive oil'),
#  ('shrimp', 'nan'),
#  ('shrimp', 'milk'),
#  ('olive oil', 'nan'),
#  ('olive oil', 'milk'),
#  ('nan', 'milk'),
#  ('olive oil', 'soup'),
#  ('olive oil', 'nan'),
#  ('olive oil', 'milk'),
#  ('soup', 'nan'),
#  ('soup', 'milk'),
#  ('nan', 'milk'),
#  ('olive oil', 'spaghetti'),
#  ('olive oil', 'nan'),
#  ('olive oil', 'milk'),
#  ('spaghetti', 'nan'),
#  ('spaghetti', 'milk'),
#  ('nan', 'milk'),
#  ('soup', 'nan'),
#  ('soup', 'milk'),
#  ('soup', 'tomatoes'),
#  ('nan', 'milk'),
#  ('nan', 'tomatoes'),
#  ('milk', 'tomatoes'),
#  ('whole wheat pasta', 'spaghetti'),
#  ('whole wheat pasta', 'nan'),
#  ('whole wheat pasta', 'milk'),
#  ('spaghetti', 'nan'),
#  ('spaghetti', 'milk'),
#  ('nan', 'milk'),
#  ('olive oil', 'mineral water'),
#  ('olive oil', 'soup'),
#  ('olive oil', 'nan'),
#  ('mineral water', 'soup'),
#  ('mineral water', 'nan'),
#  ('soup', 'nan'),
#  ('whole wheat pasta', 'olive oil'),
#  ('whole wheat pasta', 'mineral water'),
#  ('whole wheat pasta', 'nan'),
#  ('olive oil', 'mineral water'),
#  ('olive oil', 'nan'),
#  ('mineral water', 'nan'),
#  ('pancakes', 'olive oil'),
#  ('pancakes', 'spaghetti'),
#  ('pancakes', 'nan'),
#  ('olive oil', 'spaghetti'),
#  ('olive oil', 'nan'),
#  ('spaghetti', 'nan'),
#  ('olive oil', 'spaghetti'),
#  ('olive oil', 'nan'),
#  ('olive oil', 'tomatoes'),
#  ('spaghetti', 'nan'),
#  ('spaghetti', 'tomatoes'),
#  ('nan', 'tomatoes'),
#  ('whole wheat rice', 'spaghetti'),
#  ('whole wheat rice', 'nan'),
#  ('whole wheat rice', 'tomatoes'),
#  ('spaghetti', 'nan'),
#  ('spaghetti', 'tomatoes'),
#  ('nan', 'tomatoes'),
#  ('eggs', 'nan'),
#  ('eggs', 'chocolate'),
#  ('eggs', 'mineral water'),
#  ('eggs', 'ground beef'),
#  ('nan', 'chocolate'),
#  ('nan', 'mineral water'),
#  ('nan', 'ground beef'),
#  ('chocolate', 'mineral water'),
#  ('chocolate', 'ground beef'),
#  ('mineral water', 'ground beef'),
#  ('frozen vegetables', 'nan'),
#  ('frozen vegetables', 'chocolate'),
#  ('frozen vegetables', 'mineral water'),
#  ('frozen vegetables', 'ground beef'),
#  ('nan', 'chocolate'),
#  ('nan', 'mineral water'),
#  ('nan', 'ground beef'),
#  ('chocolate', 'mineral water'),
#  ('chocolate', 'ground beef'),
#  ('mineral water', 'ground beef'),
#  ('frozen vegetables', 'spaghetti'),
#  ('frozen vegetables', 'nan'),
#  ('frozen vegetables', 'chocolate'),
#  ('frozen vegetables', 'ground beef'),
#  ('spaghetti', 'nan'),
#  ('spaghetti', 'chocolate'),
#  ('spaghetti', 'ground beef'),
#  ('nan', 'chocolate'),
#  ('nan', 'ground beef'),
#  ('chocolate', 'ground beef'),
#  ('frozen vegetables', 'nan'),
#  ('frozen vegetables', 'chocolate'),
#  ('frozen vegetables', 'milk'),
#  ('frozen vegetables', 'mineral water'),
#  ('nan', 'chocolate'),
#  ('nan', 'milk'),
#  ('nan', 'mineral water'),
#  ('chocolate', 'milk'),
#  ('chocolate', 'mineral water'),
#  ('milk', 'mineral water'),
#  ('frozen vegetables', 'spaghetti'),
#  ('frozen vegetables', 'nan'),
#  ('frozen vegetables', 'chocolate'),
#  ('frozen vegetables', 'milk'),
#  ('spaghetti', 'nan'),
#  ('spaghetti', 'chocolate'),
#  ('spaghetti', 'milk'),
#  ('nan', 'chocolate'),
#  ('nan', 'milk'),
#  ('chocolate', 'milk'),
#  ('frozen vegetables', 'shrimp'),
#  ('frozen vegetables', 'nan'),
#  ('frozen vegetables', 'chocolate'),
#  ('frozen vegetables', 'mineral water'),
#  ('shrimp', 'nan'),
#  ('shrimp', 'chocolate'),
#  ('shrimp', 'mineral water'),
#  ('nan', 'chocolate'),
#  ('nan', 'mineral water'),
#  ('chocolate', 'mineral water'),
#  ('spaghetti', 'nan'),
#  ('spaghetti', 'chocolate'),
#  ('spaghetti', 'olive oil'),
#  ('spaghetti', 'mineral water'),
#  ('nan', 'chocolate'),
#  ('nan', 'olive oil'),
#  ('nan', 'mineral water'),
#  ('chocolate', 'olive oil'),
#  ('chocolate', 'mineral water'),
#  ('olive oil', 'mineral water'),
#  ('shrimp', 'spaghetti'),
#  ('shrimp', 'nan'),
#  ('shrimp', 'chocolate'),
#  ('shrimp', 'mineral water'),
#  ('spaghetti', 'nan'),
#  ('spaghetti', 'chocolate'),
#  ('spaghetti', 'mineral water'),
#  ('nan', 'chocolate'),
#  ('nan', 'mineral water'),
#  ('chocolate', 'mineral water'),
#  ('frozen vegetables', 'eggs'),
#  ('frozen vegetables', 'nan'),
#  ('frozen vegetables', 'milk'),
#  ('frozen vegetables', 'mineral water'),
#  ('eggs', 'nan'),
#  ('eggs', 'milk'),
#  ('eggs', 'mineral water'),
#  ('nan', 'milk'),
#  ('nan', 'mineral water'),
#  ('milk', 'mineral water'),
#  ('frozen smoothie', 'spaghetti'),
#  ('frozen smoothie', 'nan'),
#  ('frozen smoothie', 'milk'),
#  ('frozen smoothie', 'mineral water'),
#  ('spaghetti', 'nan'),
#  ('spaghetti', 'milk'),
#  ('spaghetti', 'mineral water'),
#  ('nan', 'milk'),
#  ('nan', 'mineral water'),
#  ('milk', 'mineral water'),
#  ('frozen vegetables', 'nan'),
#  ('frozen vegetables', 'milk'),
#  ('frozen vegetables', 'mineral water'),
#  ('frozen vegetables', 'ground beef'),
#  ('nan', 'milk'),
#  ('nan', 'mineral water'),
#  ('nan', 'ground beef'),
#  ('milk', 'mineral water'),
#  ('milk', 'ground beef'),
#  ('mineral water', 'ground beef'),
#  ('frozen vegetables', 'spaghetti'),
#  ('frozen vegetables', 'nan'),
#  ('frozen vegetables', 'milk'),
#  ('frozen vegetables', 'ground beef'),
#  ('spaghetti', 'nan'),
#  ('spaghetti', 'milk'),
#  ('spaghetti', 'ground beef'),
#  ('nan', 'milk'),
#  ('nan', 'ground beef'),
#  ('milk', 'ground beef'),
#  ('frozen vegetables', 'spaghetti'),
#  ('frozen vegetables', 'nan'),
#  ('frozen vegetables', 'mineral water'),
#  ('frozen vegetables', 'ground beef'),
#  ('spaghetti', 'nan'),
#  ('spaghetti', 'mineral water'),
#  ('spaghetti', 'ground beef'),
#  ('nan', 'mineral water'),
#  ('nan', 'ground beef'),
#  ('mineral water', 'ground beef'),
#  ('frozen vegetables', 'nan'),
#  ('frozen vegetables', 'milk'),
#  ('frozen vegetables', 'olive oil'),
#  ('frozen vegetables', 'mineral water'),
#  ('nan', 'milk'),
#  ('nan', 'olive oil'),
#  ('nan', 'mineral water'),
#  ('milk', 'olive oil'),
#  ('milk', 'mineral water'),
#  ('olive oil', 'mineral water'),
#  ('frozen vegetables', 'soup'),
#  ('frozen vegetables', 'nan'),
#  ('frozen vegetables', 'milk'),
#  ('frozen vegetables', 'mineral water'),
#  ('soup', 'nan'),
#  ('soup', 'milk'),
#  ('soup', 'mineral water'),
#  ('nan', 'milk'),
#  ('nan', 'mineral water'),
#  ('milk', 'mineral water'),
#  ('frozen vegetables', 'spaghetti'),
#  ('frozen vegetables', 'nan'),
#  ('frozen vegetables', 'milk'),
#  ('frozen vegetables', 'mineral water'),
#  ('spaghetti', 'nan'),
#  ('spaghetti', 'milk'),
#  ('spaghetti', 'mineral water'),
#  ('nan', 'milk'),
#  ('nan', 'mineral water'),
#  ('milk', 'mineral water'),
#  ('frozen vegetables', 'shrimp'),
#  ('frozen vegetables', 'spaghetti'),
#  ('frozen vegetables', 'nan'),
#  ('frozen vegetables', 'mineral water'),
#  ('shrimp', 'spaghetti'),
#  ('shrimp', 'nan'),
#  ('shrimp', 'mineral water'),
#  ('spaghetti', 'nan'),
#  ('spaghetti', 'mineral water'),
#  ('nan', 'mineral water'),
#  ('frozen vegetables', 'spaghetti'),
#  ('frozen vegetables', 'nan'),
#  ('frozen vegetables', 'tomatoes'),
#  ('frozen vegetables', 'mineral water'),
#  ('spaghetti', 'nan'),
#  ('spaghetti', 'tomatoes'),
#  ('spaghetti', 'mineral water'),
#  ('nan', 'tomatoes'),
#  ('nan', 'mineral water'),
#  ('tomatoes', 'mineral water'),
#  ('spaghetti', 'nan'),
#  ('spaghetti', 'olive oil'),
#  ('spaghetti', 'mineral water'),
#  ('spaghetti', 'ground beef'),
#  ('nan', 'olive oil'),
#  ('nan', 'mineral water'),
#  ('nan', 'ground beef'),
#  ('olive oil', 'mineral water'),
#  ('olive oil', 'ground beef'),
#  ('mineral water', 'ground beef'),
#  ('spaghetti', 'nan'),
#  ('spaghetti', 'tomatoes'),
#  ('spaghetti', 'mineral water'),
#  ('spaghetti', 'ground beef'),
#  ('nan', 'tomatoes'),
#  ('nan', 'mineral water'),
#  ('nan', 'ground beef'),
#  ('tomatoes', 'mineral water'),
#  ('tomatoes', 'ground beef'),
#  ('mineral water', 'ground beef'),
#  ('spaghetti', 'nan'),
#  ('spaghetti', 'milk'),
#  ('spaghetti', 'olive oil'),
#  ('spaghetti', 'mineral water'),
#  ('nan', 'milk'),
#  ('nan', 'olive oil'),
#  ('nan', 'mineral water'),
#  ('milk', 'olive oil'),
#  ('milk', 'mineral water'),
#  ('olive oil', 'mineral water'),
#  ('spaghetti', 'nan'),
#  ('spaghetti', 'milk'),
#  ('spaghetti', 'tomatoes'),
#  ('spaghetti', 'mineral water'),
#  ('nan', 'milk'),
#  ('nan', 'tomatoes'),
#  ('nan', 'mineral water'),
#  ('milk', 'tomatoes'),
#  ('milk', 'mineral water'),
#  ('tomatoes', 'mineral water')]

# %%
import pandas
df2 = pandas.DataFrame(itemsets)
df2.columns = ['Source','Target']
df2['Type'] = 'undirected'
df2.to_csv('transactions.csv')
